# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
image_1 = Image.open("dataset/1.jpg")

# %%
image_1 = np.array(image_1)

# %%
plt.imshow(image_1)
plt.show()

# %%
image_2 = Image.open("dataset/2.jpg")
image_2 = np.array(image_2)
plt.imshow(image_2)
plt.show()

image_2[200:225, 240:265] = [255, 0, 0]
image_2[230 - 15:230 + 15, 310 - 15:310 + 15] = [255, 0, 0]
plt.imshow(image_2)
plt.show()

# %%
image_2[251:253, 211:213]
# Out:
# array([[[255, 255,   0],
#         [255, 255,   0]],
#
#        [[255, 255,   0],
#         [255, 255,   0]]], dtype=uint8)
