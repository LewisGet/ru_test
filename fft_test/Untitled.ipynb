# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft
from scipy.io import wavfile

# %%
def print_fft(file_name, size=5):
    fs, data = wavfile.read(file_name) # load the data
    a = data.T[0] # this is a two channel soundtrack, I get the first track
    b = [(ele/2**8.)*2-1 for ele in a] # this is 8-bit track, b is now normalized on [-1,1)
    c = fft(b) # calculate fourier transform (complex numbers list)
    d = int(len(c)/size)  # you only need half of the fft list (real signal symmetry)
    
    np.save(file_name + "_fft.npy", c)
    
    plt.figure(1)
    plt.title(file_name + "_size_" + str(size))
    plt.plot(abs(c[:(d - 1)]))
    plt.show()

# %%
import glob

# %%
files = glob.glob('./*.wav')

# %%
for file in files:
    print_fft(file)
# Out:
# /usr/local/lib/python3.4/dist-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
for file in files:
    print_fft(file, 10)
# Out:
# /usr/local/lib/python3.4/dist-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
for file in files:
    print_fft(file, 15)
# Out:
# /usr/local/lib/python3.4/dist-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
for file in files:
    print_fft(file, 20)
# Out:
# /usr/local/lib/python3.4/dist-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
for file in files:
    print_fft(file, 25)
# Out:
# /usr/local/lib/python3.4/dist-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)
